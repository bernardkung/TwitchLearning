# %% [markdown]
# Read all data files, and use the file names to define the file to read, and the name of the data frame to read it into.

# %%
import os
import numpy as np
import pandas as pd

# %%
data_list = os.listdir("..\\Data\\")
name_list = []
for file in data_list:
    name_list.append(file.split("#")[-1].split(".")[0])

# %%
data_dct
# Out:
# {'overwatchleague_2018_02_24':        month  day      time            username  \
#  0        Feb   24  00:41:45              zinicr
#  1        Feb   24  00:41:45       sugoi_bokchoy
#  2        Feb   24  00:41:45        acenightfall
#  3        Feb   24  00:41:45              ani127
#  4        Feb   24  00:41:45            sugulite
#  5        Feb   24  00:41:45             isac631
#  6        Feb   24  00:41:45               rezm3
#  7        Feb   24  00:41:46         cassserolle
#  8        Feb   24  00:41:46       destroyandrew
#  9        Feb   24  00:41:46          igetdenied
#  10       Feb   24  00:41:46        azureocereus
#  11       Feb   24  00:41:46       hanz0_hattori
#  12       Feb   24  00:41:46              surg44
#  13       Feb   24  00:41:47        avinavbehera
#  14       Feb   24  00:41:47             rdx_009
#  15       Feb   24  00:41:47             spazzzo
#  16       Feb   24  00:41:47      skaraokstreams
# ...
