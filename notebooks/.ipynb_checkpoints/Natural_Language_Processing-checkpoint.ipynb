# %% [markdown]
# # Twitch Learning
# ## Analyzing Chat Logs
# ___
# 2018 | Bernard Kung
# ___
#
# This is my development notebook for analyzing Twitch logs.

# %% [markdown]
# ## Goals
#
# 1. Convert timestamps columns (month, day, time) to proper timestamp format column
# 2. Basic Analysis
#     - message count per second
#     - average message count per second
#     - outlier detection
#     - highlight moment detection
# 3. Tokenize messages
# 3. Basic NLP Analysis
#     - words per message
#     - most frequent words per second
#     - most common message (copy-pasta)
#     - chat sentiment

# %%
import os
import glob

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pylab as plt
import seaborn as sns
# %matplotlib inline

# %%
import nltk
# nltk.download('punkt')

# %% [markdown]
# ### Convert to timestamps.
# Most of the columns were read in as objects.
#
# Probably should re-consider how I process the chat logs.

# %%
log = pd.read_json(r'..\Data\overwatchleague_2018_02_24.txt', orient='split')

# %%
log["timestamp"] = pd.to_datetime(log.month + " " + log.day.astype(str) + ", " + "2018"+ 
                                  " " + log.time.astype(str))

# %% [markdown]
# ### Basic Analysis
#
# message count per second

# %% [markdown]
# Weird things: so the group_by creates a group_by object. Now initially I'm creating a new data frame to store aggregated data. However I want to rename the column, but I'm not sure how to concisely create a new data frame from a group_by and rename it immediately. Morever, using reset index now is problematic because i add other group_by results onto the dataframe later. So i need to either reset index on those, which may not line up, or just do this.

# %%
log_agg = log[["timestamp", "message"]].groupby("timestamp").count()
log_agg.head()
# Out:
#                      message
# timestamp
# 2018-02-24 00:41:45        7
# 2018-02-24 00:41:46        6
# 2018-02-24 00:41:47        8
# 2018-02-24 00:41:48        9
# 2018-02-24 00:41:49        3

# %%
#log_agg = log_agg.reset_index()

# %% [markdown]
# ### Tokenization
#
# tokenize messages, create a token count

# %%
log['token'] = log.apply(lambda row: nltk.word_tokenize(row['message']), axis = 1)

# %%
log['token_count'] = log['token'].apply(lambda x: len(x))

# %%
log_agg["avg_token_count"] = log[["timestamp", "token_count"]].groupby("timestamp").mean()
log_agg.head()
# Out:
#                      message  avg_token_count
# timestamp
# 2018-02-24 00:41:45        7         2.142857
# 2018-02-24 00:41:46        6         2.166667
# 2018-02-24 00:41:47        8         4.875000
# 2018-02-24 00:41:48        9         3.555556
# 2018-02-24 00:41:49        3         2.333333

# %%
log_agg = log_agg.reset_index()
log_agg = log_agg.rename(columns = {'message':'num_message'})
log_agg.head()
# Out:
#             timestamp  num_message  avg_token_count
# 0 2018-02-24 00:41:45            7         2.142857
# 1 2018-02-24 00:41:46            6         2.166667
# 2 2018-02-24 00:41:47            8         4.875000
# 3 2018-02-24 00:41:48            9         3.555556
# 4 2018-02-24 00:41:49            3         2.333333

# %% [markdown]
# #### Basic Distribution Plots
# message count per second
# token count per message per second

# %%
sns.lineplot(data=log_agg, x='timestamp', y='num_message')

# %% [markdown]
# There's a weird outlier here

# %%
log_agg[log_agg['num_message']>400]['timestamp']
# Out:
# 1088   2018-02-24 01:01:51
# Name: timestamp, dtype: datetime64[ns]

# %%
log[log['timestamp']=='2018-02-24 01:01:51']
# Out:
#      month  day      time            username  \
# 7757   Feb   24  01:01:51          its_tenzin
# 7758   Feb   24  01:01:51             legos__
# 7759   Feb   24  01:01:51        nathandplays
# 7760   Feb   24  01:01:51          willowport
# 7761   Feb   24  01:01:51             nserror
# 7762   Feb   24  01:01:51            ow_z0mby
# 7763   Feb   24  01:01:51        teenageriot_
# 7764   Feb   24  01:01:51             1c3m4nz
# 7765   Feb   24  01:01:51       saberhagensan
# 7766   Feb   24  01:01:51  thequiveringdancer
# 7767   Feb   24  01:01:51            bojingus
# 7768   Feb   24  01:01:51           quizzis33
# 7769   Feb   24  01:01:51         onegirlriot
# 7770   Feb   24  01:01:51       galedagenhart
# 7771   Feb   24  01:01:51       whatismyname3
# 7772   Feb   24  01:01:51             krisnft
# 7773   Feb   24  01:01:51         klevoman238
# 7774   Feb   24  01:01:51          damnedfox_
# 7775   Feb   24  01:01:51       lisettmartin8
# ...

# %% [markdown]
# At this point, I have a basic tokenization of messages by word, and some basic exploratory analysis in terms of number of messages, average messages, length of message, etc.

# %% [markdown]
# Group all the messages into a single corpus, as well as smaller by second corpuses. NLP seems to focus more on larger corpuses (corpi?).

# %%
log.head()
# Out:
#   month  day      time       username  \
# 0   Feb   24  00:41:45         zinicr
# 1   Feb   24  00:41:45  sugoi_bokchoy
# 2   Feb   24  00:41:45   acenightfall
# 3   Feb   24  00:41:45         ani127
# 4   Feb   24  00:41:45       sugulite
#
#                                              message           timestamp  \
# 0                                                 yo 2018-02-24 00:41:45
# 1                                             OWLLDN 2018-02-24 00:41:45
# 2                                          Fleta god 2018-02-24 00:41:45
# 3  OWLAna OWLMercy OWLSombra OWLTorbjorn OWLReape... 2018-02-24 00:41:45
# 4                                           PogChamp 2018-02-24 00:41:45
#
#                                                token  token_count
# 0                                               [yo]            1
# 1                                           [OWLLDN]            1
# 2                                       [Fleta, god]            2
# ...

# %%
message = log['message'].str.cat(sep=' ')
message_tokens = nltk.word_tokenize(message)

# %%
message_tokens.count("PogChamp")
# Out:
# 3094

# %%
len(message_tokens)
# Out:
# 165013

# %%
message_tokens.index('Kappa')
# Out:
# 2291

# %%
message_tokens[2291]
# Out:
# 'Kappa'

# %%
def lexical_diversity(text):
    return len(set(text)) / len(text) 

def percentage(count, total):
     return 100 * count / total

# %%
lexical_diversity(message_tokens)
# Out:
# 0.09008987170707762

# %%
message_freq = nltk.FreqDist(message_tokens)
message_freq.plot(20, cumulative=False)

# %% [markdown]
# Is there a way to determine the most commonly used emote?

# %%
message_unique_tokens =  set(message_tokens)

# %%
emotes = pd.read_json('https://twitchemotes.com/api_cache/v3/global.json').transpose()

# %%
emotes.head()
# Out:
#                           code emoticon_set  id
# JKanStyle            JKanStyle            0  15
# OptimizePrime    OptimizePrime            0  16
# StoneLightning  StoneLightning            0  17
# TheRinger            TheRinger            0  18
# RedCoat                RedCoat            0  22

# %%
message_emotes = [t for t in message_unique_tokens if t in emotes['code']]
message_emotes
# Out:
# ['HSCheers',
#  'Kappu',
#  'FutureMan',
#  'twitchRaid',
#  'AsianGlow',
#  'SSSsss',
#  'WholeWheat',
#  'PrimeMe',
#  'DBstyle',
#  'NotATK',
#  'FBtouchdown',
#  'HassaanChop',
#  'KevinTurtle',
#  'ResidentSleeper',
#  'ThankEgg',
#  'HotPokket',
#  'PJSalt',
#  'bleedPurple',
#  'ShadyLulu',
#  'Jebaited',
#  'BatChest',
#  'CoolStoryBob',
#  'HeyGuys',
#  'PunOko',
#  'YouDontSay',
#  'ShazBotstix',
#  'WutFace',
#  'StoneLightning',
#  'PowerUpL',
#  'BloodTrail',
#  'MingLee',
#  'RlyTho',
#  'EleGiggle',
#  'BigPhish',
#  'Squid3',
#  'NomNom',
#  'DrinkPurple',
#  'Mau5',
#  'TearGlove',
#  'UnSane',
#  'Squid2',
#  'ArsonNoSexy',
#  'riPepperonis',
#  'FrankerZ',
#  'CorgiDerp',
#  'SwiftRage',
#  'cmonBruh',
#  'TwitchRPG',
#  'TwitchLit',
#  'GingerPower',
#  'KonCha',
#  'PurpleStar',
#  'KomodoHype',
#  'StinkyCheese',
#  'RedCoat',
#  'TwitchUnity',
#  'CoolCat',
#  'TheTarFu',
#  'BibleThump',
#  'NinjaGrumpy',
#  'SeriousSloth',
#  'VoteNay',
#  'Kappa',
# ...

# %%
msg_emote_count = [message_tokens.count(tkn) for tkn in message_emotes]
msg_dict = {"emote": message_emotes, "count": msg_emote_count}
msg_df = pd.DataFrame(msg_dict)
msg_df.head()
# Out:
#         emote  count
# 0    HSCheers      9
# 1       Kappu     12
# 2   FutureMan      1
# 3  twitchRaid      2
# 4   AsianGlow      6

# %%
msg_df= msg_df.sort_values('count', ascending=False).reset_index(drop=True)

# %%
msg_df.head(15)
# Out:
#               emote  count
# 0               LUL   3218
# 1          PogChamp   3094
# 2             Kappa    382
# 3           TriHard    295
# 4            Squid2    288
# 5           GivePLZ    264
# 6        BibleThump    254
# 7          BabyRage    248
# 8            SSSsss    210
# 9          cmonBruh    208
# 10         Kreygasm    203
# 11          WutFace    182
# 12       KappaPride    163
# 13         DansGame    145
# 14  ResidentSleeper    141

# %%
plt.figure(figsize=(8, 8))
sns.barplot(data=msg_df.head(20), x='count', y='emote')

# %% [markdown]
# So top 2 emotes by far are LUL and PogChamp. By comparison, it looks like there are a lot of tokens that still come out ahead like "?", "!", etc.
# So next step, or probably the step I should've done, is to work with tagging to remove punctuations, and all those other common terms that have a name that I also skipped over.
#
# Long term it'd be nice to look at word pairs. But the end goal is to dig out patterns based on tagged token types for longer form copy-paste memes, e.g. "GivePLZ SHANGHAI GivePLZ DRAGONS GivePLZ TAKE GivePLZ OUR GivePLZ ENERGY GivePLZ"

# %% [markdown]
# Is there a way to see the growth and decline of the most popular emotes and eventually memes.
# 1. Need some kind of metric for identifying moments where an emote is spiking in intensity.
#     a. Use the overall most used emotes
#     b. Use the overall messages per second
#         - Distribution of messages per second (mps)
#         - Find the top 10% of seconds with the highest mps.
# 2. Graph the usage density of the emote.

# %%
log_agg.describe()
# Out:
#         num_message  avg_token_count
# count  17578.000000     17578.000000
# mean       2.195699         4.873320
# std        4.850198         5.199119
# min        1.000000         1.000000
# 25%        1.000000         1.666667
# 50%        1.000000         3.000000
# 75%        2.000000         6.000000
# max      488.000000        62.000000

# %%
top10_agg = log_agg.nlargest(round(log_agg.shape[0]/10), 'num_message')
top10_agg.describe()
# Out:
#        num_message  avg_token_count
# count  1758.000000      1758.000000
# mean      8.428328         3.355267
# std      13.677072         1.930680
# min       4.000000         1.000000
# 25%       5.000000         2.142857
# 50%       6.000000         2.857143
# 75%       9.000000         4.000000
# max     488.000000        21.000000

# %%
log_agg['timestamp'].describe()
# Out:
# count                   17578
# unique                  17578
# top       2018-02-24 08:31:33
# freq                        1
# first     2018-02-24 00:41:45
# last      2018-02-24 10:32:51
# Name: timestamp, dtype: object

# %% [markdown]
# Seems to be a problem here, the chat log goes for 10 hours, starting at 12:41AM and going until 10:30AM. The broadcast ends at a time I don't specifically know. I'm going to use a rolling average to try to wiggle it out.

# %%
log_agg['rolling_average'] = log_agg['num_message'].rolling(60).mean()
plt.figure(figsize=(8, 8))
sns.lineplot(data = log_agg, x= 'timestamp',y='rolling_average')

# %% [markdown]
# There's a pretty clear inflection point right near the beginning. So this is probably the aftermath of the broadcast, and some weird spikes of activity. It's a little easier to see the dynamics since that big spike is drastically smoothed out. It's not amazing because there's a weird spike of activity in the very long 'dead' period. Also is there something with like a rolling second derivative that might work better?
# But more importantly I should just use what I have to find a log that's mostly live footage and use that. Anyways lets just lop it off for now, and kick it forward a little bit.

# %%
log_agg['rolling_average'].describe()
# Out:
# count    17519.000000
# mean         2.192559
# std          2.120731
# min          1.016667
# 25%          1.383333
# 50%          1.500000
# 75%          1.733333
# max         19.533333
# Name: rolling_average, dtype: float64

# %%
cutoff_time = log_agg['timestamp'][int(log_agg.shape[0]/10)]

# %%
livelog = log[log['timestamp']<=cutoff_time]
livelog.head()
# Out:
#   month  day      time       username  \
# 0   Feb   24  00:41:45         zinicr
# 1   Feb   24  00:41:45  sugoi_bokchoy
# 2   Feb   24  00:41:45   acenightfall
# 3   Feb   24  00:41:45         ani127
# 4   Feb   24  00:41:45       sugulite
#
#                                              message           timestamp  \
# 0                                                 yo 2018-02-24 00:41:45
# 1                                             OWLLDN 2018-02-24 00:41:45
# 2                                          Fleta god 2018-02-24 00:41:45
# 3  OWLAna OWLMercy OWLSombra OWLTorbjorn OWLReape... 2018-02-24 00:41:45
# 4                                           PogChamp 2018-02-24 00:41:45
#
#                                                token  token_count
# 0                                               [yo]            1
# 1                                           [OWLLDN]            1
# 2                                       [Fleta, god]            2
# ...

# %% [markdown]
# Count the LULs per second. Never thought I'd be here...even until I was here.
#
# Anyways I want to count individual emote usage both if it's used at all, and for each time it's used. Then I need the total of both metrics per second.
#
# For a list of emotes,
# 1. Count the number of uses of that emote per second.
# 2. Count the number of messages per second containing that emote at least once.

# %%
log_agg['corpus'] =  log.groupby('timestamp')['message'].apply(lambda x: x.str.cat(sep = ' ')).reset_index()['message']
log_agg['token'] = log_agg.apply(lambda x: nltk.word_tokenize(x['corpus']), axis=1)
log_agg.head()
# Out:
#             timestamp  num_message  avg_token_count  rolling_average  \
# 0 2018-02-24 00:41:45            7         2.142857              NaN
# 1 2018-02-24 00:41:46            6         2.166667              NaN
# 2 2018-02-24 00:41:47            8         4.875000              NaN
# 3 2018-02-24 00:41:48            9         3.555556              NaN
# 4 2018-02-24 00:41:49            3         2.333333              NaN
#
#                                               corpus  \
# 0  yo OWLLDN Fleta god OWLAna OWLMercy OWLSombra ...
# 1  YOU HAVE BEEN PROBED woah PogChamp PogChmp Pog...
# 2  sf shock finna lose real bad DSP WAS BETTER LU...
# 3  owlseo100 DSP TOBI OWLLucio poggers BRONZE RAN...
# 4   OWLSEO OWLJunkrat OWLJunkrat OWLSEO gg OWLSFS 50
#
#                                                token
# 0  [yo, OWLLDN, Fleta, god, OWLAna, OWLMercy, OWL...
# 1  [YOU, HAVE, BEEN, PROBED, woah, PogChamp, PogC...
# 2  [sf, shock, finna, lose, real, bad, DSP, WAS, ...
# ...

# %%
top5_emotes = msg_df.loc[0:4, 'emote']

# %%
for emote in top5_emotes:
    log_agg[emote] = log_agg.token.apply(lambda x: x.count(emote))
#    log_agg['b_' + emote] = log_agg.token.apply(lambda x: x.count(emote) > 0)

# %%
livelog_agg = log_agg[log_agg['timestamp']<=cutoff_time]
livelog_agg.head()
# Out:
#             timestamp  num_message  avg_token_count  rolling_average  \
# 0 2018-02-24 00:41:45            7         2.142857              NaN
# 1 2018-02-24 00:41:46            6         2.166667              NaN
# 2 2018-02-24 00:41:47            8         4.875000              NaN
# 3 2018-02-24 00:41:48            9         3.555556              NaN
# 4 2018-02-24 00:41:49            3         2.333333              NaN
#
#                                               corpus  \
# 0  yo OWLLDN Fleta god OWLAna OWLMercy OWLSombra ...
# 1  YOU HAVE BEEN PROBED woah PogChamp PogChmp Pog...
# 2  sf shock finna lose real bad DSP WAS BETTER LU...
# 3  owlseo100 DSP TOBI OWLLucio poggers BRONZE RAN...
# 4   OWLSEO OWLJunkrat OWLJunkrat OWLSEO gg OWLSFS 50
#
#                                                token  LUL  PogChamp  Kappa  \
# 0  [yo, OWLLDN, Fleta, god, OWLAna, OWLMercy, OWL...    1         1      0
# 1  [YOU, HAVE, BEEN, PROBED, woah, PogChamp, PogC...    0         2      0
# ...

# %%
plt.figure(figsize=(12,6))
sns.lineplot(x='timestamp',y='LUL',data=livelog_agg)

# %%
#log_agg['rolling_average'] = log_agg['num_message'].rolling(60).mean()
livelog_agg['smoothed_LUL'] = livelog_agg['LUL'].rolling(5).mean()
plt.figure(figsize=(12,6))
sns.lineplot(x='timestamp',y='smoothed_LUL',data=livelog_agg)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
log_agg.columns
# Out:
# Index(['timestamp', 'num_message', 'avg_token_count', 'rolling_average',
#        'corpus', 'token', 'LUL', 'PogChamp', 'Kappa', 'TriHard', 'Squid2',
#        'n_LUL', 'b_LUL', 'n_PogChamp', 'b_PogChamp', 'n_Kappa', 'b_Kappa',
#        'n_TriHard', 'b_TriHard', 'n_Squid2', 'b_Squid2'],
#       dtype='object')

# %%
log_melt = pd.melt(log_agg[['timestamp','LUL','PogChamp','Kappa','TriHard','Squid2']], id_vars=['timestamp'], 
        value_vars=['LUL','PogChamp','Kappa','TriHard','Squid2'])
livelog_melt = log_melt[log_melt['timestamp']<=cutoff_time]
livelog_melt.head()
# Out:
#             timestamp variable  value
# 0 2018-02-24 00:41:45      LUL      1
# 1 2018-02-24 00:41:46      LUL      0
# 2 2018-02-24 00:41:47      LUL      1
# 3 2018-02-24 00:41:48      LUL      0
# 4 2018-02-24 00:41:49      LUL      0

# %%
plt.figure(figsize=(12,6))
sns.lineplot(x='timestamp', y='value', hue='variable', alpha=0.8, data=livelog_melt)

# %% [markdown]
# ##### Part 1: Count the number of uses of that emote per second
#
# So the plot is pretty spiky. It's just the nature of chat that emote usage swings wildly and quickly, and it's further exacerbated by the amount of time covered. So I could smooth it a little by using the rolling average trick, but the problem is that it's reasonable to use a few seconds, but that doesn't help the spikiness. Using a much longer window (say 120 seconds) helps with the spikiness a lot, but it's unreasonable to draw conclusions from a 2 minute window.
#
# So probably need some further thought on effective visuals. I would still like some kind of pretty overlapping KDE plots...
